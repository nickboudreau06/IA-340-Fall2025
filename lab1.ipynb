# %% [markdown]
# # lab1

# %% [markdown]
# This is my first lab.

# %%
import pandas as pd 

covid_data = pd.read_csv("s3://ia-340-fall-2025-1078447/data (1).csv")
covid_data.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/fsspec/registry.py:298: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# ...

# %%
ai_use = pd.read_csv("s3://ia-340-fall-2025-1078447/San_Francisco_AI_Use_Inventory__Chapter_22J_.csv")
ai_use.head()
# Out:
#                                               id department  \
# 0  DPH-Evolv Express concealed weapons detection        DPH
# 1                       DPH-Ischemaview Rapid AI        DPH
# 2                                      DPH-Mirai        DPH
# 3                                    DPH-TalView        DPH
# 4                   DPH-TransMed Inspirata Epath        DPH
#
#                          q1_tool_vendor_name  \
# 0  Evolv Express concealed weapons detection
# 1                       Ischemaview Rapid AI
# 2                                      Mirai
# 3                                    TalView
# 4                   TransMed Inspirata Epath
#
#                                          q2_ purpose  \
# 0  Evolv Express is a next-generation, AI-powered...
# 1  Rapid AI is used to identify and guide treatme...
# 2  Mirai is an AI tool that identifies high-risk ...
# 3  TalView’s AI proctoring tool is designed to mo...
# 4  This tool is a rule-based system that automate...
#
# ...
